# %% [markdown]
# ##

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(-2*np.pi, +2*np.pi, 0.01)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
y = np.cos(x)

# %%
plt.plot(x,y)
